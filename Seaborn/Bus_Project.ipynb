# %%
import seaborn as sns
import pandas as pd 
import numpy as np

# %%
data = pd.read_csv('./data/MTA_Bus_Mean_Distance_Between_Failures__Beginning_2015.csv')
data.head(20)
# Out:
#          Month        Borough  Monthly Miles  Monthly Road Call Count  \
# 0   01/01/2015          Bronx        2166371                      434
# 1   01/01/2015       Brooklyn        2901602                      576
# 2   01/01/2015      Manhattan        1283763                      458
# 3   01/01/2015         Queens        4032200                      810
# 4   01/01/2015  Staten Island        2029610                      230
# 5   02/01/2015          Bronx        1962258                      518
# 6   02/01/2015       Brooklyn        2767879                      571
# 7   02/01/2015      Manhattan        1200788                      422
# 8   02/01/2015         Queens        3675299                      956
# 9   02/01/2015  Staten Island        1906088                      278
# 10  03/01/2015          Bronx        2258765                      609
# 11  03/01/2015       Brooklyn        3117255                      617
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 5 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Month                    630 non-null    object
#  1   Borough                  630 non-null    object
#  2   Monthly Miles            630 non-null    int64
#  3   Monthly Road Call Count  630 non-null    int64
#  4   Monthly MDBF             630 non-null    int64
# dtypes: int64(3), object(2)
# memory usage: 24.7+ KB

# %%
data.isnull().sum()
# Out:
# Month                      0
# Borough                    0
# Monthly Miles              0
# Monthly Road Call Count    0
# Monthly MDBF               0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# 0

# %%
data['Month'] = pd.to_datetime(data['Month'])
ax = sns.lineplot(data, x=data.Month, y='Monthly Miles', hue=data.Borough)
sns.move_legend(ax, loc='upper left', bbox_to_anchor=(1,1))

# %%
ax = sns.lineplot(data, x=data.Month, y='Monthly MDBF', hue=data.Borough)
sns.move_legend(ax, 'upper left', bbox_to_anchor = (1,1))

# %%
sns.boxplot(data, x='Borough', y='Monthly MDBF')
# Out:
# <Axes: xlabel='Borough', ylabel='Monthly MDBF'>

# %%
sns.violinplot(data, x='Borough', y='Monthly MDBF')
# Out:
# <Axes: xlabel='Borough', ylabel='Monthly MDBF'>

# %%
sns.scatterplot(data, x='Monthly Miles', y='Monthly MDBF', hue=data.Borough)
# Out:
# <Axes: xlabel='Monthly Miles', ylabel='Monthly MDBF'>

# %%
sns.heatmap(data[['Monthly Miles', 'Monthly Road Call Count', 'Monthly MDBF']].corr(), annot=True)
# Out:
# <Axes: >
