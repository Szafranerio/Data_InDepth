# %%
import pandas as pd 
import numpy as np
import seaborn as sns
from sklearn import metrics

# %%
data = pd.read_csv('./cotton/data.csv')
data.head()
# Out:
#    Quantity  Price per Piece  Needle Type_200N  Needle Type_250N  \
# 0      8900             0.56                 0                 0
# 1      5200             0.54                 0                 0
# 2      6600             0.76                 0                 1
# 3      8200             0.64                 1                 0
# 4      7800             0.72                 0                 1
#
#    Cylinder Type_Single  Half Terry  Cotton  Bamboo  Cylinder Type_Double  \
# 0                     1           1       1       0                     0
# 1                     0           1       0       1                     1
# 2                     1           0       0       1                     0
# 3                     0           1       0       1                     1
# 4                     1           0       0       1                     0
#
#    Black
# 0      0
# 1      0
# 2      1
# 3      0
# 4      1

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
X = data[['Quantity', 'Needle Type_200N', 'Needle Type_250N', 'Cylinder Type_Single', 'Half Terry', 'Cotton', 'Bamboo', 'Cylinder Type_Double', 'Black']]
y = data['Price per Piece']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=101)

# %%
lm = LinearRegression()

# %%
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
lm.coef_
# Out:
# array([-4.97233201e-07,  5.75058459e-02,  9.95964569e-02, -3.55683600e-03,
#         8.10587873e-03, -2.31647267e-03,  2.31647267e-03,  3.55683600e-03,
#         3.86112162e-03])

# %%
pred = lm.predict(X_test)
pred
# Out:
# array([0.70627207, 0.67194153, 0.61329205, 0.60529296, 0.66344747,
#        0.60757063, 0.61350054, 0.66388312, 0.61024799, 0.70902739,
#        0.66735831, 0.60836077, 0.5980821 , 0.61419667, 0.60524323,
#        0.66497703, 0.66718539, 0.7016651 , 0.7189233 , 0.71700784,
#        0.6971316 , 0.70567539, 0.6158754 , 0.72183968, 0.7205966 ,
#        0.61840585, 0.67323208, 0.67025094, 0.71388071, 0.70922628,
#        0.66758318, 0.71787911, 0.66601578, 0.70726653, 0.72044743,
#        0.71353265, 0.67489348, 0.7087528 , 0.71348519, 0.62119904,
#        0.62129848, 0.61294399, 0.60994965, 0.70290818, 0.60114765,
#        0.70350486, 0.67900322, 0.70627207, 0.6984244 , 0.69897136,
#        0.67474431, 0.6706086 , 0.61144135, 0.7079075 , 0.60554383,
#        0.60955187, 0.7182769 , 0.6984244 , 0.70942291, 0.66235355,
#        0.72154134, 0.72169051, 0.70054521, 0.712441  , 0.6160743 ,
#        0.70168885, 0.65855405, 0.60172058, 0.66462897, 0.70780805,
# ...

# %%
print(metrics.mean_absolute_error(y_test, pred))
print(metrics.mean_squared_error(y_test, pred))
print(np.sqrt(metrics.mean_squared_error(y_test, pred)))
# Out:
# 0.04225183725600873
# 0.002633024579160646
# 0.05131300594547786

# %% [markdown]
# PREDICTION

# %%
example_features = pd.DataFrame({
    'Quantity': [5000],  
    'Needle Type_200N': [1], 
    'Needle Type_250N': [0], 
    'Cylinder Type_Single': [1],  
    'Half Terry': [1],  
    'Cotton': [0], 
    'Bamboo': [1],
    'Cylinder Type_Double': [0], 
    'Black': [1]  # 
})

predicted_price = lm.predict(example_features)
print("Predicted Price per Piece:", predicted_price[0])
# Out:
# Predicted Price per Piece: 0.6731326327173816
