# %%
from CS50_Harvard import square
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 from CS50_Harvard import square
#
# ModuleNotFoundError: No module named 'CS50_Harvard'
