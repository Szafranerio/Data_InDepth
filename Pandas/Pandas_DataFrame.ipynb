# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math as math
import random

# %%
mc_data = pd.read_csv('./data/Mcdonalds.csv', index_col='Item')
mc_data
# Out:
#                                                              Category  \
# Item
# Egg McMuffin                                                Breakfast
# Egg White Delight                                           Breakfast
# Sausage McMuffin                                            Breakfast
# Sausage McMuffin with Egg                                   Breakfast
# Sausage McMuffin with Egg Whites                            Breakfast
# ...                                                               ...
# McFlurry with Oreo Cookies (Small)                 Smoothies & Shakes
# McFlurry with Oreo Cookies (Medium)                Smoothies & Shakes
# McFlurry with Oreo Cookies (Snack)                 Smoothies & Shakes
# McFlurry with Reese's Peanut Butter Cups (Medium)  Smoothies & Shakes
# McFlurry with Reese's Peanut Butter Cups (Snack)   Smoothies & Shakes
#
#                                                       Serving Size  Calories  \
# Item
# ...

# %%
mc_data.count()
# Out:
# Category                         260
# Serving Size                     260
# Calories                         260
# Calories from Fat                260
# TotalFat                         260
# Total Fat (% Daily Value)        260
# Saturated Fat                    260
# Saturated Fat (% Daily Value)    260
# Trans Fat                        260
# Cholesterol                      260
# Cholesterol (% Daily Value)      260
# Sodium                           260
# Sodium (% Daily Value)           260
# Carbohydrates                    260
# Carbohydrates (% Daily Value)    260
# Dietary Fiber                    260
# Dietary Fiber (% Daily Value)    260
# Sugars                           260
# Protein                          260
# Vitamin A (% Daily Value)        260
# Vitamin C (% Daily Value)        260
# Calcium (% Daily Value)          260
# Iron (% Daily Value)             260
# dtype: int64

# %%
mc_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 260 entries, Egg McMuffin to McFlurry with Reese's Peanut Butter Cups (Snack)
# Data columns (total 23 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Serving Size                   260 non-null    object
#  2   Calories                       260 non-null    int64
#  3   Calories from Fat              260 non-null    int64
#  4   TotalFat                       260 non-null    float64
#  5   Total Fat (% Daily Value)      260 non-null    int64
#  6   Saturated Fat                  260 non-null    float64
#  7   Saturated Fat (% Daily Value)  260 non-null    int64
#  8   Trans Fat                      260 non-null    float64
#  9   Cholesterol                    260 non-null    int64
#  10  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
mc_data.Calories.value_counts()
# Out:
# Calories
# 0      16
# 340    10
# 430    10
# 280     9
# 250     8
#        ..
# 640     1
# 800     1
# 740     1
# 620     1
# 810     1
# Name: count, Length: 78, dtype: int64

# %%
#search by index
mc_data.iloc[1]
# Out:
# Category                              Breakfast
# Serving Size                     4.8 oz (135 g)
# Calories                                    250
# Calories from Fat                            70
# TotalFat                                    8.0
# Total Fat (% Daily Value)                    12
# Saturated Fat                               3.0
# Saturated Fat (% Daily Value)                15
# Trans Fat                                   0.0
# Cholesterol                                  25
# Cholesterol (% Daily Value)                   8
# Sodium                                      770
# Sodium (% Daily Value)                       32
# Carbohydrates                                30
# Carbohydrates (% Daily Value)                10
# Dietary Fiber                                 4
# Dietary Fiber (% Daily Value)                17
# Sugars                                        3
# Protein                                      18
# Vitamin A (% Daily Value)                     6
# ...

# %%
#Search by position or value
mc_data.loc['McFlurry with Oreo Cookies (Snack)']
# Out:
# Category                         Smoothies & Shakes
# Serving Size                         6.7 oz (190 g)
# Calories                                        340
# Calories from Fat                               100
# TotalFat                                       11.0
# Total Fat (% Daily Value)                        17
# Saturated Fat                                   6.0
# Saturated Fat (% Daily Value)                    29
# Trans Fat                                       0.0
# Cholesterol                                      30
# Cholesterol (% Daily Value)                       9
# Sodium                                          190
# Sodium (% Daily Value)                            8
# Carbohydrates                                    53
# Carbohydrates (% Daily Value)                    18
# Dietary Fiber                                     1
# Dietary Fiber (% Daily Value)                     2
# Sugars                                           43
# ...

# %%
#For one column
mc_data['Calories']
# Out:
# Item
# Egg McMuffin                                         300
# Egg White Delight                                    250
# Sausage McMuffin                                     370
# Sausage McMuffin with Egg                            450
# Sausage McMuffin with Egg Whites                     400
#                                                     ...
# McFlurry with Oreo Cookies (Small)                   510
# McFlurry with Oreo Cookies (Medium)                  690
# McFlurry with Oreo Cookies (Snack)                   340
# McFlurry with Reese's Peanut Butter Cups (Medium)    810
# McFlurry with Reese's Peanut Butter Cups (Snack)     410
# Name: Calories, Length: 260, dtype: int64

# %%
#For more than one column, there is a need of two brackets 
mc_data[['Calories', 'TotalFat']]
# Out:
#                                                    Calories  TotalFat
# Item
# Egg McMuffin                                            300      13.0
# Egg White Delight                                       250       8.0
# Sausage McMuffin                                        370      23.0
# Sausage McMuffin with Egg                               450      28.0
# Sausage McMuffin with Egg Whites                        400      23.0
# ...                                                     ...       ...
# McFlurry with Oreo Cookies (Small)                      510      17.0
# McFlurry with Oreo Cookies (Medium)                     690      23.0
# McFlurry with Oreo Cookies (Snack)                      340      11.0
# McFlurry with Reese's Peanut Butter Cups (Medium)       810      32.0
# McFlurry with Reese's Peanut Butter Cups (Snack)        410      16.0
#
# [260 rows x 2 columns]
