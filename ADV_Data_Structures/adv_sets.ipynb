# %%
s = set()
s.add(1)
s.add(2)
s
# Out:
# {1, 2}

# %%
s.clear()
s
# Out:
# set()

# %%
s = {1,2,3,4,5}
s_copy = s.copy()

# %%
s.difference(s_copy)
# Out:
# set()

# %%
s1 = {1,2,3}
s2 = {1,2,4}
s1.intersection(s2)
# Out:
# {1, 2}
