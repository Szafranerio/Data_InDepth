# %%
s = 'hello'
s
# Out:
# 'hello'

# %%
s.capitalize()
# Out:
# 'Hello'

# %%
s.count('o')
# Out:
# 1

# %%
s.find('h')
# Out:
# 0

# %%
s.center(20, 'z')
# Out:
# 'zzzzzzzhellozzzzzzzz'

# %%
s.isalnum()
# Out:
# True

# %%
s.isalpha()
# Out:
# True

# %%
s.isdecimal()
# Out:
# False

# %%
s.split('e')
# Out:
# ['h', 'llo']

# %%
s.partition('l')
# Out:
# ('he', 'l', 'lo')
