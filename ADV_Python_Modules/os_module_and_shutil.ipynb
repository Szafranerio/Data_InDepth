# %%
pwd
# Out:
# '/Users/bartlomiejszafran/Desktop/Git/GitHub/Data_InDepth/ADV_Python_Modules'

# %%
f = open('test.txt', 'w+')
f.write('Test module')
f.close()

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/bartlomiejszafran/Desktop/Git/GitHub/Data_InDepth/ADV_Python_Modules'

# %%
#For current file
os.listdir()
# Out:
# ['os_module_and_shutil.ipynb', 'Collection_Modules.py', 'test.txt']

# %%
#Can be used for any location on computer
os.listdir('/Users')
# Out:
# ['.localized', 'bartlomiejszafran', 'Shared']

# %%
import shutil

# %%
#Allows to move files
shutil.move('test.txt', '/Users/bartlomiejszafran/Desktop')
# Out:
# '/Users/bartlomiejszafran/Desktop/test.txt'
