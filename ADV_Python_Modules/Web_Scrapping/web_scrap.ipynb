# %%
import requests
import bs4

# %%
res = requests.get('https://www.example.com/')
type(res)
# Out:
# requests.models.Response

# %%
res.text
# Out:
# '<!doctype html>\n<html>\n<head>\n    <title>Example Domain</title>\n\n    <meta charset="utf-8" />\n    <meta http-equiv="Content-type" content="text/html; charset=utf-8" />\n    <meta name="viewport" content="width=device-width, initial-scale=1" />\n    <style type="text/css">\n    body {\n        background-color: #f0f0f2;\n        margin: 0;\n        padding: 0;\n        font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;\n        \n    }\n    div {\n        width: 600px;\n        margin: 5em auto;\n        padding: 2em;\n        background-color: #fdfdff;\n        border-radius: 0.5em;\n        box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);\n    }\n    a:link, a:visited {\n        color: #38488f;\n        text-decoration: none;\n    }\n    @media (max-width: 700px) {\n        div {\n            margin: 0 auto;\n            width: auto;\n        }\n    }\n    </style>    \n</head>\n\n<body>\n<div>\n   
# ...

# %%
#BS
#FOr better reading
soup = bs4.BeautifulSoup(res.text,'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Example Domain</title>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="Content-type"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <style type="text/css">
#     body {
#         background-color: #f0f0f2;
#         margin: 0;
#         padding: 0;
#         font-family: -apple-system, system-ui, BlinkMacSystemFont, "Segoe UI", "Open Sans", "Helvetica Neue", Helvetica, Arial, sans-serif;
#
#     }
#     div {
#         width: 600px;
#         margin: 5em auto;
#         padding: 2em;
#         background-color: #fdfdff;
#         border-radius: 0.5em;
#         box-shadow: 2px 3px 7px 2px rgba(0,0,0,0.02);
#     }
#     a:link, a:visited {
#         color: #38488f;
#         text-decoration: none;
#     }
#     @media (max-width: 700px) {
#         div {
#             margin: 0 auto;
#             width: auto;
#         }
#     }
#     </style>
# </head>
# <body>
# <div>
# ...

# %%
#Selects what you want and it will print
soup.select('title')[0].getText()
# Out:
# 'Example Domain'

# %%
soup.select('p')[1].getText()
# Out:
# 'More information...'

# %%
soup.select('head')[0].getText()
# Out:
# '\nExample Domain\n\n\n\n\n'

# %%
#Grabbing a class

# %%
res = requests.get('https://en.wikipedia.org/wiki/J%C3%B3zef_Pi%C5%82sudski')
soup = bs4.BeautifulSoup(res.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Józef Piłsudski - Wikipedia</title>
# ...

# %%
content = soup.select('.vector-toc-text')
content[1].text
# Out:
# '\n1\nEarly life\n'

# %%
for i in soup.select('.vector-toc-text'):
    print (i.text)
# Out:
# (Top)
#
# 1
# Early life
#
#
# 1.1
# Siberian exile
#
#
# 2
# Polish Socialist Party
#
#
# 2.1
# Armed resistance
#
#
# 2.2
# Russian Revolution of 1905
#
#
# 2.3
# Prelude to World War I
#
#
# 3
# World War I
#
#
# 4
# Rebuilding Poland
#
#
# 4.1
# Head of state
#
#
# 4.2
# First policies
#
#
# 5
# Polish–Soviet War
#
#
# 5.1
# "Miracle at the Vistula"
#
#
# 6
# Retirement and coup
#
#
# 7
# In government
#
#
# 7.1
# Internal politics
#
#
# 7.2
# Foreign policy
#
#
# 7.3
# Economic policy
#
#
# 8
# Religious views
#
#
# 9
# Death
#
#
# 9.1
# Funeral
#
#
# 10
# Legacy
#
#
# 11
# Descendants
#
#
# 12
# Honours
#
#
# 13
# See also
#
#
# 14
# Notes
#
#
# 15
# References
#
#
# 16
# Sources
#
#
# 17
# Further reading
#
#
# 18
# External links

# %% [markdown]
# Image webscrap

# %%
img_res = requests.get('https://pl.wikipedia.org/wiki/Deep_Blue')
soup = bs4.BeautifulSoup(img_res.text, 'lxml')
soup
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="pl">
# <head>
# <meta charset="utf-8"/>
# <title>Deep Blue – Wikipedia, wolna encyklopedia</title>
# ...

# %%
computer = soup.select(".mw-file-description")[0]
computer
# Out:
# <a class="mw-file-description" href="/wiki/Plik:Deep_Blue.jpg"><img class="mw-file-element" data-file-height="601" data-file-width="400" decoding="async" height="331" src="//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/220px-Deep_Blue.jpg" srcset="//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/330px-Deep_Blue.jpg 1.5x, //upload.wikimedia.org/wikipedia/commons/b/be/Deep_Blue.jpg 2x" width="220"/></a>

# %% [markdown]
# <img src="//upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/220px-Deep_Blue.jpg">

# %%
#Save img and print binary file of the img
img_link = requests.get("https://upload.wikimedia.org/wikipedia/commons/thumb/b/be/Deep_Blue.jpg/220px-Deep_Blue.jpg")
img_link.content
# Out:
# b'\xff\xd8\xff\xe1\x00\x80Exif\x00\x00MM\x00*\x00\x00\x00\x08\x00\x05\x01\x1a\x00\x05\x00\x00\x00\x01\x00\x00\x00J\x01\x1b\x00\x05\x00\x00\x00\x01\x00\x00\x00R\x01(\x00\x03\x00\x00\x00\x01\x00\x02\x00\x00\x01;\x00\x02\x00\x00\x00\x1e\x00\x00\x00Z\x02\x13\x00\x03\x00\x00\x00\x01\x00\x01\x00\x00\x00\x00\x00\x00\x00\x00\x00H\x00\x00\x00\x01\x00\x00\x00H\x00\x00\x00\x01Jim Gardner - thejimmyjob.com\x00\xff\xe2\x02@ICC_PROFILE\x00\x01\x01\x00\x00\x020ADBE\x02\x10\x00\x00mntrRGB XYZ \x07\xcf\x00\x06\x00\x03\x00\x00\x00\x00\x00\x00acspAPPL\x00\x00\x00\x00none\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf6\xd6\x00\x01\x00\x00\x00\x00\xd3-ADBE\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\ncprt\x00\x00\x00\xfc\x00\x00\x002desc\x00\x00\x010\x00\x00\x00kwtpt\x00\x00\x01\x9c\x00\x00\x00\x14bkpt\x00\x00\x01\xb0\x00\x00\x00\x14rT
# ...

# %%
f = open('my_computer.jpg', 'wb')
f.write(img_link.content)
# Out:
# 18448
